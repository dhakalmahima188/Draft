# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
train_df = pd.read_csv('./dataset/train.csv')
# train_df.head()
sns.countplot(train_df['category'],x=train_df['category'])
# help(sns.countplot)
# Out:
# <AxesSubplot: xlabel='category', ylabel='count'>

# %%
count=train_df.category.unique().size
freq =train_df.category.value_counts()
freq

# %%
freq.plot(kind='bar')

# %%
train_df = pd.read_csv('./dataset/test.csv')
train_df.head()

# %%
ntrain_df=train_test_split(train_df,test_size=0.000001,random_state=42)
ntrain_df
